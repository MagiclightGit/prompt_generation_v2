# %%
import os
from IPython.display import HTML
import pandas as pd
import random

# %%
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_rows', 1000)

df = pd.read_csv('controlnet_vs.txt')
# df = pd.read_excel("/data/yangelfang/ws_test_data/cdp_useaudio.xlsx")
# df = df.loc[(df["概率1"]<0.1)]
# df = df.loc[(df["概率2"]>0.3)]
df
# Out:
#                                        分镜ID  \
# 0   7ce5noezvafma27_a002670p9uj_2449000.jpg
# 1     7ce5noezvafma27_a002670p9uj_77320.jpg
# 2   7ce5noezvafma27_a00269ix3l8_2676000.jpg
# 3    7ce5noezvafma27_a00269ix3l8_371640.jpg
# 4    7ce5noezvafma27_a0026rsv224_558320.jpg
# 5   7ce5noezvafma27_a0026vb3ahw_2076000.jpg
# 6    7ce5noezvafma27_a0026vb3ahw_212000.jpg
# 7   7ce5noezvafma27_a0026vb3ahw_2612640.jpg
# 8   7ce5noezvafma27_b0026112jlm_1437640.jpg
# 9   7ce5noezvafma27_c002613xs6z_2637640.jpg
# 10  7ce5noezvafma27_c002613xs6z_2717640.jpg
# 11   7ce5noezvafma27_c002613xs6z_585000.jpg
# 12  7ce5noezvafma27_c002681ax0n_1757320.jpg
# 13   7ce5noezvafma27_c002681ax0n_192320.jpg
# 14  7ce5noezvafma27_d00267aaeqh_1511000.jpg
# 15  7ce5noezvafma27_d00267aaeqh_1555640.jpg
# 16   7ce5noezvafma27_d00267aaeqh_564000.jpg
# 17   7ce5noezvafma27_e00269vh4ze_366320.jpg
# 18  7ce5noezvafma27_e0026isdppx_1273320.jpg
# 19   7ce5noezvafma27_e0026isdppx_211320.jpg
# ...

# %%
dfx = pd.DataFrame({
    "动作":list(df["动作"]),
    "原图":['<image src="https://d1h9telkp7p6c5.cloudfront.net/layout-source/%s" height="250" width="400" controls = autoplay> ' %_ for _ in df["分镜ID"]],
    "Pose":['<image src="https://d1h9telkp7p6c5.cloudfront.net/layout-source/%s" height="250" width="400" controls = autoplay> ' %_ for _ in df["分镜ID"]],
    # "动作":list(df["动作"]),
    "xin_openpose":[f'<image src="https://aigc-outputs.s3.amazonaws.com/cf-outputs/{x}/f_{x}/{x}_0_0.jpg" height="250" width="400" controls = autoplay> ' for x in df["xinr_pose"]],
    "openpose_xl":[f'<image src="https://aigc-outputs.s3.amazonaws.com/cf-outputs/{x}/f_{x}/{x}_0_0.jpg" height="250" width="400" controls = autoplay> ' for x in df["openposexl"]],
    "magic_pose":[f'<image src="https://aigc-outputs.s3.amazonaws.com/cf-outputs/{x}/f_{x}/{x}_0_0.jpg" height="250" width="400" controls = autoplay> ' for x in df["magic_pose"]],
    # "图片ID":list(df["img"]),
    # "人数":list(df["人数"]),
    # "位置":list(df["位置"]),
    
})
# dfx
HTML(dfx[0:].to_html().replace("&lt;", "<").replace("&gt;", ">"))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>动作</th>
#       <th>原图</th>
#       <th>xin_openpose</th>
#       <th>openpose_xl</th>
#       <th>magic_pose</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td